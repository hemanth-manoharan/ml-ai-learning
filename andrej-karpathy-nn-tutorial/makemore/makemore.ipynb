# %%
words = open('makemore/names.txt', 'r').read().splitlines()

# %%
print(len(words))
# Out:
# 32033

# %%
words[:5]
# Out:
# ['emma', 'olivia', 'ava', 'isabella', 'sophia']

# %%
for w in words[:1]:
    w_new = ['#'] + list(w) + ['$']
    for (x, y) in zip(w_new, w_new[1:]):
        print(x + " " + y)
# Out:
# # e
# e m
# m m
# m a
# a $
